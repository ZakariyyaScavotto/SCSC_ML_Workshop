# %% [markdown]
# <h1><b>DATA SCIENCE

# %% [markdown]
# <h2>We can use pandas for our data science needs. Pandas is perfect for Exploratory Data Analysis (EDA) and data manipulation. It is a fast, powerful, and flexible open-source data analysis and manipulation tool built on top of the Python programming language.

# %% [markdown]
# - <h3> Run cells using shift, enter or the run button at the top

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# if those don't work, download them to your computer
#pip install numpy

# %%
# file needs to be in same folder
file_name = 'ClassicHit.csv'

# Use pandas to read the CSV file into a DataFrame
df = pd.read_csv(file_name)

# %%
df
# Out:
#                                 Track          Artist  Year  Duration  \
# 0                    Hey Jack Kerouac  10,000 Maniacs  1987    206413
# 1                    Like the Weather  10,000 Maniacs  1987    236653
# 2             What's the Matter Here?  10,000 Maniacs  1987    291173
# 3                          Trouble Me  10,000 Maniacs  1989    193560
# 4               Candy Everybody Wants  10,000 Maniacs  1992    185960
# ...                               ...             ...   ...       ...
# 15145  7 Seconds (feat. Neneh Cherry)  Youssou N'Dour  1994    306226
# 15146                          Birima  Youssou N'Dour  1995    228373
# 15147                             Set  Youssou N'Dour  2004    226826
# 15148                Africa Remembers  Youssou N'Dour  2007    560466
# 15149                       Wiri-Wiri  Youssou N'Dour  2007    247466
#
#        Time_Signature  Danceability  Energy  Key  Loudness  Mode  Speechiness  \
# ...

# %%
df.head()
#df.tail()
#df.head(10)
# Out:
#                      Track          Artist  Year  Duration  Time_Signature  \
# 0         Hey Jack Kerouac  10,000 Maniacs  1987    206413               4
# 1         Like the Weather  10,000 Maniacs  1987    236653               4
# 2  What's the Matter Here?  10,000 Maniacs  1987    291173               4
# 3               Trouble Me  10,000 Maniacs  1989    193560               4
# 4    Candy Everybody Wants  10,000 Maniacs  1992    185960               4
#
#    Danceability  Energy  Key  Loudness  Mode  Speechiness  Acousticness  \
# 0         0.616   0.511    6   -15.894     1       0.0279       0.03840
# 1         0.770   0.459    1   -17.453     1       0.0416       0.11200
# 2         0.593   0.816    9    -7.293     1       0.0410       0.00449
# 3         0.861   0.385    2   -10.057     1       0.0341       0.15400
# 4         0.622   0.876   10    -6.310     1       0.0305       0.01930
#
#    Instrumentalness  Liveness  Valence    Tempo  Popularity      Genre
# ...

# %%
df.shape
# returns tuple of row/column count
# Out:
# (15150, 18)

# %%
df.columns
# Out:
# Index(['Track', 'Artist', 'Year', 'Duration', 'Time_Signature', 'Danceability',
#        'Energy', 'Key', 'Loudness', 'Mode', 'Speechiness', 'Acousticness',
#        'Instrumentalness', 'Liveness', 'Valence', 'Tempo', 'Popularity',
#        'Genre'],
#       dtype='object')

# %% [markdown]
# Columns details:
# * Track - Title of the song
# * Artist - Name of the performing artist/band
# * Year - The year the track was released
# * Duration - Length of the track in milliseconds
# * Time Signature - Musical time signature of the track = How many beats are in each bar
# * Danceability - How suitable the track is for dancing, values from 0.0 to 1.0
# * Energy - Measure of the intensity of the track, values from 0.0 to 1.0
# * Key - The key of the track, eg: 0 = C
# * Loudness - The overall loudness of the track in decibels, dB.
# * Mode - The specific type of scale used, major (1) or minor (0)
# * Speechiness - Measure of the presence of spoken words or vocal activity in a track rather than musical sounds
# * Acousticness - How acoustic is the track, 0.0 to 1.0
# * Instrumentalness - Measure of the likelihood that the track is instrumental, ranging from 0.0 to 1.0.
# * Liveness - measure of the presence of a live audience in the track, ranging from 0.0 to 1.0
# * Valence - measures the emotional quality of a track, specifically how positive or negative it sounds, value between 0.0 and 1.0
# * Tempo - Speed of the track in beats per minute (BPM)
# * Popularity - measure of the track's popularity, ranging from 0 to 100
# * Genre - Pop, Metal, EDM, Rap etc

# %%
df.head()
# Out:
#                      Track          Artist  Year  Duration  Time_Signature  \
# 0         Hey Jack Kerouac  10,000 Maniacs  1987    206413               4
# 1         Like the Weather  10,000 Maniacs  1987    236653               4
# 2  What's the Matter Here?  10,000 Maniacs  1987    291173               4
# 3               Trouble Me  10,000 Maniacs  1989    193560               4
# 4    Candy Everybody Wants  10,000 Maniacs  1992    185960               4
#
#    Danceability  Energy  Key  Loudness  Mode  Speechiness  Acousticness  \
# 0         0.616   0.511    6   -15.894     1       0.0279       0.03840
# 1         0.770   0.459    1   -17.453     1       0.0416       0.11200
# 2         0.593   0.816    9    -7.293     1       0.0410       0.00449
# 3         0.861   0.385    2   -10.057     1       0.0341       0.15400
# 4         0.622   0.876   10    -6.310     1       0.0305       0.01930
#
#    Instrumentalness  Liveness  Valence    Tempo  Popularity      Genre
# ...

# %%
df.info()
# returns column names and data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15150 entries, 0 to 15149
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track             15150 non-null  object
#  1   Artist            15150 non-null  object
#  2   Year              15150 non-null  int64
#  3   Duration          15150 non-null  int64
#  4   Time_Signature    15150 non-null  int64
#  5   Danceability      15150 non-null  float64
#  6   Energy            15150 non-null  float64
#  7   Key               15150 non-null  int64
#  8   Loudness          15150 non-null  float64
#  9   Mode              15150 non-null  int64
#  10  Speechiness       15150 non-null  float64
#  11  Acousticness      15150 non-null  float64
#  12  Instrumentalness  15150 non-null  float64
#  13  Liveness          15150 non-null  float64
#  14  Valence           15150 non-null  float64
#  15  Tempo             15150 non-null  float64
# ...

# %%
df.dtypes
# Out:
# Track                object
# Artist               object
# Year                  int64
# Duration              int64
# Time_Signature        int64
# Danceability        float64
# Energy              float64
# Key                   int64
# Loudness            float64
# Mode                  int64
# Speechiness         float64
# Acousticness        float64
# Instrumentalness    float64
# Liveness            float64
# Valence             float64
# Tempo               float64
# Popularity            int64
# Genre                object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Track               0
# Artist              0
# Year                0
# Duration            0
# Time_Signature      0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Mode                0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Popularity          0
# Genre               0
# dtype: int64

# %%
# we would have to clean our data and remove missing values if there were any
# you can do that with the following code:
#df = df.dropna()
# or you can fill in missing values with the following code:
# df.fillna(df.mean(['Duration']), inplace=True)

# %% [markdown]
# <h4>We would have to clean our data and remove missing values if there were any. You can do that with the following code:
#     <code>df = df.dropna()</code>  <br>
#
# or you can fill in missing values with the following code: <code>df.fillna(df.mean(['Duration']), inplace=True)</code>

# %%
df.describe()
# Out:
#                Year      Duration  Time_Signature  Danceability        Energy  \
# count  15150.000000  1.515000e+04    15150.000000  15150.000000  15150.000000
# mean    1984.709769  2.413028e+05        3.921650      0.574667      0.617691
# std       19.482460  1.057966e+05        0.348322      0.166208      0.239527
# min     1899.000000  2.300000e+04        0.000000      0.000000      0.000098
# 25%     1971.000000  1.803700e+05        4.000000      0.461000      0.442000
# 50%     1983.000000  2.228525e+05        4.000000      0.582000      0.644000
# 75%     1998.000000  2.751530e+05        4.000000      0.696000      0.819000
# max     2024.000000  3.060650e+06        5.000000      0.988000      0.999000
#
#                 Key      Loudness          Mode   Speechiness  Acousticness  \
# count  15150.000000  15150.000000  15150.000000  15150.000000  15150.000000
# mean       5.257624     -9.154545      0.696634      0.075791      0.302651
# ...

# %%
df.describe(include='object')
# Out:
#         Track      Artist  Genre
# count   15150       15150  15150
# unique  13771        3083     19
# top      Lady  Elton John    Pop
# freq        8          54   3669

# %%
# we could look at specific columns
df['Key']
# df [['Key']]
# or multiple columns
df[['Key', 'Duration']]
# Out:
#        Key  Duration
# 0        6    206413
# 1        1    236653
# 2        9    291173
# 3        2    193560
# 4       10    185960
# ...    ...       ...
# 15145    1    306226
# 15146   10    228373
# 15147    0    226826
# 15148    5    560466
# 15149    5    247466
#
# [15150 rows x 2 columns]

# %%
# for Key, 0 = C
# so we can see how many songs are in the key of C and beyond
#(df['Key'] == 0).sum()
df['Key'].value_counts()
# Out:
# 0     1872
# 7     1782
# 9     1614
# 2     1592
# 5     1349
# 1     1317
# 4     1220
# 11    1144
# 10    1008
# 8      939
# 6      804
# 3      509
# Name: Key, dtype: int64

# %%
# we can even visualize this data
df['Key'].value_counts().plot(kind='bar')
xlabel = 'Key'
ylabel = 'Count'
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title('Number of Songs by Key')
plt.show()

# %%
# and how many different genres are we dealing with
df['Genre'].nunique()
#genres = list(df['Genre'].unique())
#genres
# Out:
# 19

# %%
# So we can practice a little data science and correlation exploration 
#with key and genre
# see the count of songs in each key for each genre
genre_and_key = df.groupby('Genre')['Key'].value_counts().reset_index(name='Count')
genre_and_key.head(50)
# Out:
#         Genre  Key  Count
# 0   Alt. Rock    2    107
# 1   Alt. Rock    7    101
# 2   Alt. Rock    4     92
# 3   Alt. Rock    9     92
# 4   Alt. Rock    0     90
# 5   Alt. Rock   11     57
# 6   Alt. Rock    1     54
# 7   Alt. Rock    8     45
# 8   Alt. Rock    5     42
# 9   Alt. Rock    6     40
# 10  Alt. Rock   10     37
# 11  Alt. Rock    3     23
# 12      Blues    9    100
# 13      Blues    0     95
# 14      Blues    2     91
# 15      Blues    7     91
# 16      Blues    5     62
# 17      Blues   10     51
# 18      Blues    4     49
# 19      Blues   11     42
# 20      Blues    1     31
# 21      Blues    8     30
# 22      Blues    3     27
# 23      Blues    6     14
# 24    Country    9    112
# 25    Country    7    109
# 26    Country    2    106
# 27    Country    0    101
# 28    Country    4     88
# 29    Country    5     72
# 30    Country   10     56
# 31    Country    8     47
# 32    Country   11     47
# 33    Country    1     42
# ...

# %%
# Find and display duplicate rows where all values are identical
duplicate_rows = df[df.duplicated(keep=False)]
print(duplicate_rows)
# Out:
#           Track Artist  Year  Duration  Time_Signature  Danceability  Energy  \
# 3639  Happy Now   Zedd  2019    207029               3         0.503   0.741
# 3640  Happy Now   Zedd  2019    207029               3         0.503   0.741
#
#       Key  Loudness  Mode  Speechiness  Acousticness  Instrumentalness  \
# 3639    4    -5.128     1        0.047         0.579          0.000001
# 3640    4    -5.128     1        0.047         0.579          0.000001
#
#       Liveness  Valence   Tempo  Popularity Genre
# 3639    0.0712    0.458  88.335          63   EDM
# 3640    0.0712    0.458  88.335          63   EDM

# %%
# drop duplicates
df = df.drop_duplicates()
df
# Out:
#                                 Track          Artist  Year  Duration  \
# 0                    Hey Jack Kerouac  10,000 Maniacs  1987    206413
# 1                    Like the Weather  10,000 Maniacs  1987    236653
# 2             What's the Matter Here?  10,000 Maniacs  1987    291173
# 3                          Trouble Me  10,000 Maniacs  1989    193560
# 4               Candy Everybody Wants  10,000 Maniacs  1992    185960
# ...                               ...             ...   ...       ...
# 15145  7 Seconds (feat. Neneh Cherry)  Youssou N'Dour  1994    306226
# 15146                          Birima  Youssou N'Dour  1995    228373
# 15147                             Set  Youssou N'Dour  2004    226826
# 15148                Africa Remembers  Youssou N'Dour  2007    560466
# 15149                       Wiri-Wiri  Youssou N'Dour  2007    247466
#
#        Time_Signature  Danceability  Energy  Key  Loudness  Mode  Speechiness  \
# ...

# %% [markdown]
# <h2>Now some visualizations to help us understand our data better.<br>
# <h5><b>Matplotlib</b> is a comprehensive library for creating static, animated, and interactive visualizations in Python.
# - <h5><b>Seaborn</b> is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
# Group by year and count the number of tracks
tracks_per_year = df.groupby('Year').size().sort_index()

# Plot number of tracks per year
plt.figure(figsize=(12,6))
sns.lineplot(x=tracks_per_year.index, y=tracks_per_year.values)
plt.title('Number of Tracks Released Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Tracks')
plt.show()

# %%
# Find the earliest year + # tracks in the dataset
earliest_year = df['Year'].min()
tracks_earliest_year = df[df['Year'] == earliest_year].shape[0]
print(f"The earliest year in the dataset is {earliest_year} with {tracks_earliest_year} tracks")

# Find the most recent year + # tracks in the dataset
most_recent_year = df['Year'].max()
tracks_most_recent_year = df[df['Year'] == most_recent_year].shape[0]
print(f"The most recent year in the dataset is {most_recent_year} with {tracks_most_recent_year} tracks")
# Out:
# The earliest year in the dataset is 1899 with 1 tracks
# The most recent year in the dataset is 2024 with 8 tracks

# %%
print(df[['Duration']])
# Create a temporary column for duration in minutes
df_temp = df.copy()
df_temp['Duration_min'] = df_temp['Duration'] / 60000
# Out:
#        Duration
# 0        206413
# 1        236653
# 2        291173
# 3        193560
# 4        185960
# ...         ...
# 15145    306226
# 15146    228373
# 15147    226826
# 15148    560466
# 15149    247466
#
# [15149 rows x 1 columns]

# %%
# Create a temporary column for duration in minutes
df_temp = df.copy()
df_temp['Duration_min'] = df_temp['Duration'] / 60000

# Plot duration distribution over time
plt.figure(figsize=(12,6))
sns.lineplot(x='Year', y='Duration_min', data=df_temp, estimator='mean')
# automatic confidence interval in lineplot
plt.title('Average Track Duration Over Time')
plt.xlabel('Year')
plt.ylabel('Average Duration (minutes)')
plt.show()

# %%
# Valence, Danceability and Energy over time
plt.figure(figsize=(12,6))
sns.lineplot(x='Year', y='Danceability', data=df, estimator='mean', label='Danceability')
sns.lineplot(x='Year', y='Energy', data=df, estimator='mean', label='Energy')
sns.lineplot(x='Year', y='Valence', data=df, estimator='mean', label='Valence')
plt.title('Valence, Danceability and Energy Over Time')
plt.xlabel('Year')
plt.ylabel('Average Value')
plt.legend()
plt.show()

# Speechiness and Instrumentalness over time
plt.figure(figsize=(12,6))
sns.lineplot(x='Year', y='Speechiness', data=df, estimator='mean', label='Speechiness')
sns.lineplot(x='Year', y='Instrumentalness', data=df, estimator='mean', label='Instrumentalness')
plt.title('Speechiness and Instrumentalness Over Time')
plt.xlabel('Year')
plt.ylabel('Average Value')
plt.legend()
plt.show()

# Acousticness and Liveness over time
plt.figure(figsize=(12,6))
sns.lineplot(x='Year', y='Acousticness', data=df, estimator='mean', label='Acousticness')
sns.lineplot(x='Year', y='Liveness', data=df, estimator='mean', label='Liveness')
plt.title('Acousticness and Liveness Over Time')
plt.xlabel('Year')
plt.ylabel('Average Value')
plt.legend()
plt.show()

# %%
# Loudness over time
plt.figure(figsize=(12,6))
sns.lineplot(x='Year', y='Loudness', data=df, estimator='mean')
plt.title('Average Track Loudness Over Time')
plt.xlabel('Year')
plt.ylabel('Loudness (dB)')
plt.show()

# %%
# create 2 boxplot of 1990 and 2024 for tempo
plt.figure(figsize=(12,6))
sns.boxplot(x='Year', y='Tempo', data=df[(df['Year'] == 1990) | (df['Year'] == 2024)])
plt.title('Tempo Distribution in 1990 and 2024')
plt.xlabel('Year')
plt.ylabel('Tempo')
# Out:
# Text(0, 0.5, 'Tempo')

# %%
# Set figure size
plt.figure(figsize=(12, 6))

# Create a box plot to show the distribution of tempo over time
sns.boxplot(x='Year', y='Tempo', data=df)

# Set plot title and labels
plt.title('Distribution of Tempo Over Time')
plt.xlabel('Year')
plt.ylabel('Tempo (BPM)')

# Show the plot
plt.xticks(rotation=90)
plt.show()

# %%
# clean outliers
# Find and display rows with Tempo value of zero
rows_with_zero_tempo = df[df['Tempo'] == 0]
print("Rows with Tempo value of zero:")
print(rows_with_zero_tempo)

# Remove rows with Tempo value of zero
df = df[df['Tempo'] != 0]
df
# Out:
# Rows with Tempo value of zero:
#              Track           Artist  Year  Duration  Time_Signature  \
# 8298  Loop De Loop   Johnny Thunder  1963    594000               0
# 8529  Hello,Dolly!  Louis Armstrong  1964    147000               0
#
#       Danceability    Energy  Key  Loudness  Mode  Speechiness  Acousticness  \
# 8298           0.0  0.000273    1   -47.359     1          0.0         0.620
# 8529           0.0  0.405000    0    -9.935     1          0.0         0.842
#
#       Instrumentalness  Liveness  Valence  Tempo  Popularity Genre
# 8298           0.97300     0.111      0.0    0.0          61   Pop
# 8529           0.00114     0.198      0.0    0.0          67   Pop
#                                 Track          Artist  Year  Duration  \
# 0                    Hey Jack Kerouac  10,000 Maniacs  1987    206413
# 1                    Like the Weather  10,000 Maniacs  1987    236653
# 2             What's the Matter Here?  10,000 Maniacs  1987    291173
# ...

# %%
# Set figure size
plt.figure(figsize=(12, 6))

# Create a box plot to show the distribution of tempo over time
sns.boxplot(x='Year', y='Tempo', data=df)

# Set plot title and labels
plt.title('Distribution of Tempo Over Time')
plt.xlabel('Year')
plt.ylabel('Tempo (BPM)')

# Show the plot
plt.xticks(rotation=90)
plt.show()

# %%
# Grouping by year and genre to get the count of tracks per genre over time
genre_evolution = df.groupby(['Year', 'Genre']).size().unstack().fillna(0)

# Plotting the evolution of genres over time
genre_evolution.plot(figsize=(12, 6), cmap='tab20')
plt.title('Genre Evolution Over Time')
plt.ylabel('Number of Tracks')
plt.xlabel('Year')
plt.show()

# %%
# Group by Genre and count the number of tracks in each genre
genre_counts = df['Genre'].value_counts()

# Plot a bar chart for genres sorted by track count
plt.figure(figsize=(12, 6))
sns.barplot(x=genre_counts.index, y=genre_counts.values)
plt.title('Number of Tracks per Genre')
plt.xlabel('Genre')
plt.ylabel('Number of Tracks')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
plt.figure(figsize=(12, 6))

# Create a scatter plot for loudness vs. danceability
sns.scatterplot(x='Loudness', y='Danceability', data=df, alpha=0.5)

plt.title('Loudness vs. Danceability')
plt.xlabel('Loudness (dB)')
plt.ylabel('Danceability')
plt.show()

# %%
plt.figure(figsize=(14, 7))

# Calculate average popularity for each genre
average_popularity = df.groupby('Genre')['Popularity'].mean().sort_values()

# Plot the average popularity
sns.barplot(x=average_popularity.index, y=average_popularity.values)

plt.title('Average Popularity by Genre')
plt.xlabel('Genre')
plt.ylabel('Average Popularity')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
# can look at correlation between Valance, Danceability, and Energy
# Calculate correlation matrix
correlation = 1 - df[['Valence', 'Danceability', 'Energy']].corr()

# Display the correlation matrix
correlation
# Out:
#                Valence  Danceability    Energy
# Valence       0.000000      0.517021  0.817769
# Danceability  0.517021      0.000000  1.018121
# Energy        0.817769      1.018121  0.000000

# %%
# display the correlation matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='plasma', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
# Correlation matrix
plt.figure(figsize=(12,8))
correlation_matrix = df[['Danceability', 'Energy', 'Loudness', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo', 'Popularity']].corr()

# Heatmap of the correlations
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Musical Features')
plt.show()

# %%
df=df.drop('Time_Signature', axis=1)
df
# Out:
#                                 Track          Artist  Year  Duration  \
# 0                    Hey Jack Kerouac  10,000 Maniacs  1987    206413
# 1                    Like the Weather  10,000 Maniacs  1987    236653
# 2             What's the Matter Here?  10,000 Maniacs  1987    291173
# 3                          Trouble Me  10,000 Maniacs  1989    193560
# 4               Candy Everybody Wants  10,000 Maniacs  1992    185960
# ...                               ...             ...   ...       ...
# 15145  7 Seconds (feat. Neneh Cherry)  Youssou N'Dour  1994    306226
# 15146                          Birima  Youssou N'Dour  1995    228373
# 15147                             Set  Youssou N'Dour  2004    226826
# 15148                Africa Remembers  Youssou N'Dour  2007    560466
# 15149                       Wiri-Wiri  Youssou N'Dour  2007    247466
#
#        Danceability  Energy  Key  Loudness  Mode  Speechiness  Acousticness  \
# ...

# %%
highest_popularity_tracks = df.loc[df.groupby('Genre')['Popularity'].idxmax()]
print(highest_popularity_tracks[['Track','Genre','Popularity']])

plt.figure(figsize=(10, 6))
bars = plt.barh(highest_popularity_tracks['Track'], highest_popularity_tracks['Popularity'], color='skyblue')
plt.xlabel('Popularity')
plt.ylabel('Track')
plt.title('Track Popularity by Genre')

# Add genre labels to the chart
for bar, genre in zip(bars, highest_popularity_tracks['Genre']):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, genre, va='center')

plt.tight_layout()
plt.show()
# Out:
#                                       Track      Genre  Popularity
# 615                                    Iris  Alt. Rock          88
# 998                         Bad To The Bone      Blues          69
# 1646                                 9 to 5    Country          80
# 2305                          Dancing Queen      Disco          85
# 3557               Something Just Like This        EDM          88
# 4125   California Dreamin' - Single Version       Folk          80
# 4564                            Funny Thing       Funk          75
# 4779                                You Say     Gospel          72
# 5423                 What A Wonderful World       Jazz          78
# 6034                    Sweet Child O' Mine      Metal          86
# 9477                                   Babe        Pop          96
# 10380                                Dammit       Punk          68
# 11825      Yeah! (feat. Lil Jon & Ludacris)        R&B          85
# ...

# %%
df.shape
# Out:
# (15147, 17)
